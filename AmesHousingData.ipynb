# %% [markdown]
# ##**Table of Content**
#
# *   Overview
# *   Software Required
# *   Importing Library
# *   Data Import
# *   Data Formating
# *   Data Cleaning
# *   Exploratory Data Analysis
# *   Data Visualization
# *   Conclusion
# *   References

# %% [markdown]
# ##**Overview**
# For this coursework I have been assigned **Ames Housing dataset** which was recorded by Ames Assessor’s Office. This dataset contains the details of residential properties which were sold in Ames, a small city in Lowa,USA in the year 2006-2010. The dataset has total 2930 findings and it also has 23 ordinal, 14 discrete, 20 consistent and 23 nominal variables associated with it for evaluating home estimations. In ames dataset we have total 2930 rows and 82 columns of float64(11), int64(28), object(43) datatypes. Python is a programming language which can be used to handle big data and perform complex mathematics on a data hence I have used Python programming language to perform the analysis on this dataset. In this coursework pandas, numpy, matplotlib and seaborn python libraries are used to explore and analyze the datasets.
#
# The prime goal of any business is to identify the buyers need and their aim of buying a property. After performing the analysis on this dataset we could see how the cost of property has increased exponenitally and what components had major impact on buyer's desicion while buying a property. From this investigation, We could also look at the market trend in the recent years. In this report we have seen how to access the sepcific rows and columns of large datasets, find any missing column values and ways to use visual libraries such as matplotlib and seaborn to do the data visualization.

# %% [markdown]
# ##**Software Required**
# For this coursework I have used Google Research product named as Colab. Colab is a free product and allows user to read and write python code in browser. It is specially used for machine learning and data analysis.

# %% [markdown]
# ## **Importing Library**
#
# We are using import keyword to import functions so that python modules can get access to code of other module. we are using standard shorthands like the np shorthand for NumPy, the pd shorthand for Pandas, the sns shorthands for seaborn and plt shorthand for Matplotlib.
#
# I have imported below mentioned standard libraries:-
#
# Numpy:- Numpy is most used library in python for performing any scientific computation. Using numpy we can get high performace while working with multidimensional array.
#
# Pandas:- Pandas is a open source library built on top of numpy. It is quick, simple to use and provides data analysis tools for data analysis and manipulation.
#
# Matplot:- Matplotlib is a stunning cross platform data visualization library build upon numpy. It is intended to work with the more extensive SciPy stack. It comprises of a few plots like bar, line, histogram, scatter etc.
#
# Seaborn:- Seaborn is also data visualization library built on top of matplotlib used for exploratory data analysis and data visualization.

# %%
# Step 1: Import standard libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Data Import**

# %% [markdown]
# To perform analysis on dataset firstly we need to import the data and to do that I have opened the Ames Housing dataset from the link provided in the GCU Learn then right click and save the dataset with name, ames in csv format to local system. Then create a folder named as data under My Drive folder in google drive and upload the csv file into data folder. The data available in the
# ames.csv file is just comma separated list of values and lables. Once the file is uploaded then go to Google Colab and type the below command, it will return a link to retrieve the authorization code. In below code snippet (step 2) I have used ls command to list all the contents of current directory and cd command to change the current working directory. I have also used below code to mount google drive to notebook on a runtime locally using authorization code. This also supports how read, write files and programmatically adjust sharing setting.

# %%
# Step 2: Mounting google drive locally
from google.colab import drive
drive.mount('/content/drive')
% ls      
% cd drive/   
% ls
% cd My\ Drive  
% ls
# !head -4 data/ames.csv
# Out:
# Mounted at /content/drive
# drive/  sample_data/
# /content/drive
# MyDrive/
# /content/drive/My Drive
#  bq-results-20211115-164409-qu1u4q94j0u4/  'Colab Notebooks'/      data/
#  bq-results-20211115-171708-9d60r7sjz825/  'Copy of final.ipynb'
# ...

# %% [markdown]
# In the below step 3, I have used pandas .read_csv function to import the dataset and assigned it to a ames dataframe.

# %%
# Step 3: Importing dataset by reading csv file
ames = pd.read_csv('data/ames.csv')

# %% [markdown]
# #**Data Formating**

# %% [markdown]
# Data Formating is the process of changing the format of data into usual format which can be used for analysis and comparision.

# %% [markdown]
# In step 4, I have used .info function to display information related number of rows,columns, datatype of each column and memory usage

# %%
# Step 4: Displays ames dataset information 
ames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
# To determine the names of columns in a dataset
ames3.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %% [markdown]
# Once we read the dataset, we have seen that it has two types of data:
# 1. Numerical Data - Numerical data are values which can be measured and kept in a logical order.
# 2. Categorical Data - Categorical data are informations which can be divided into groups.
#
# From the step 4 query results we could see that, there are 39 numerical and 43 categorical columns.

# %%
# Step 4: Counting the number of numerical and categorical columns
numericalColumn = list(ames.select_dtypes(exclude='object').columns)
print(f"There are {len(numericalColumn)} numerical cloumns:\n", numericalColumn)
categoricalColumn = list(ames.select_dtypes(include='object').columns)
print(f"There are {len(categoricalColumn)} categorical columns:\n", categoricalColumn)
# Out:
# There are 39 numerical cloumns:
#  ['Order', 'PID', 'MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add', 'Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd', 'Fireplaces', 'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold', 'SalePrice']
# There are 43 categorical columns:
# ...

# %% [markdown]
# In below step 5 , I have used a function to get the number of rows and columns in ames dataset.

# %%
# Step 5: Get the number of rows and columns of Dataframe
print('This dataset has {} rows and {} columns.'.format(ames.shape[0], ames.shape[1]))
# Out:
# This dataset has 2930 rows and 82 columns.

# %% [markdown]
# We could see in step 6, the median value respresented as 50% is larger than mean value of every column. Also there is notable large difference in Lot Area and BsmtFin SF 75% and max value which indicates that there are outliers in this dataset.

# %%
# Step 6: We have used .describe() function to get the statistical details of dataframe
ames.describe()
# Out:
#             Order           PID  ...      Yr Sold      SalePrice
# count  2930.00000  2.930000e+03  ...  2930.000000    2930.000000
# mean   1465.50000  7.144645e+08  ...  2007.790444  180796.060068
# std     845.96247  1.887308e+08  ...     1.316613   79886.692357
# min       1.00000  5.263011e+08  ...  2006.000000   12789.000000
# 25%     733.25000  5.284770e+08  ...  2007.000000  129500.000000
# 50%    1465.50000  5.354536e+08  ...  2008.000000  160000.000000
# 75%    2197.75000  9.071811e+08  ...  2009.000000  213500.000000
# max    2930.00000  1.007100e+09  ...  2010.000000  755000.000000
#
# [8 rows x 39 columns]

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# It is very important to perform the data cleaning before performing any kind of analysis on it. There are possibilities of data being duplicate, incorrect or mislabelled. If the data is incorrect it could generate unreliable predicitions and can impact the accuracy of the insights generated from it.
#
# In the ames dataset, we could see that there are lots of invalid and missing values which is not useful to get any insights from, hence I have dropped invalid values and filled missing values with mean of that column.

# %% [markdown]
# In step 7, I have used .head() function to get first few rows of dataset and we could see that there are several columns in the dataset each representing different values for example SalePrice column represents the prices at which houses were sold in the year 2006-2010 and other columns are like, in which neighbourhood maximum houses sold, month and year of sold. It also has few columns describing the features of property like area of the land of house i.e LotArea, condition, style of the house, overall quality and condition,roof style etc.

# %%
# Step 7: We have used .head() function to get the first few rows
ames.head()
# Out:
#    Order        PID  MS SubClass  ... Sale Type  Sale Condition  SalePrice
# 0      1  526301100           20  ...       WD           Normal     215000
# 1      2  526350040           20  ...       WD           Normal     105000
# 2      3  526351010           20  ...       WD           Normal     172000
# 3      4  526353030           20  ...       WD           Normal     244000
# 4      5  527105010           60  ...       WD           Normal     189900
#
# [5 rows x 82 columns]

# %% [markdown]
# As seen in step 8 and 9, .drop() function can be used to drop specific rows or columns as part of dataset cleaning. Since 'Alley'and 'Misc Feature' column has maximum NA value which does not have a meaningful value, I have dropped both columns and assigned the value to a ames2 dataframe and then used the head function to verify the same in step 10.

# %%
# Step 8: Drop the cloumn and assign the it to new variable ames2
ames2=ames.drop(['Alley'],axis=1)

# %%
# Step 9: Drop Column
ames2=ames.drop(['Misc Feature'],axis=1)

# %%
# Step 10: Get the first few rows after dropping few columns
ames2.head()
# Out:
#    Order        PID  MS SubClass  ... Sale Type  Sale Condition  SalePrice
# 0      1  526301100           20  ...       WD           Normal     215000
# 1      2  526350040           20  ...       WD           Normal     105000
# 2      3  526351010           20  ...       WD           Normal     172000
# 3      4  526353030           20  ...       WD           Normal     244000
# 4      5  527105010           60  ...       WD           Normal     189900
#
# [5 rows x 81 columns]

# %% [markdown]
# In step 11, I have renamed below column using rename function to remove the extra space

# %%
# Step 11: Rename columns name 
ames2.rename(columns={'Enclosed Porch':'EnclosedPorch'})
# Out:
#       Order        PID  MS SubClass  ... Sale Type  Sale Condition  SalePrice
# 0         1  526301100           20  ...       WD           Normal     215000
# 1         2  526350040           20  ...       WD           Normal     105000
# 2         3  526351010           20  ...       WD           Normal     172000
# 3         4  526353030           20  ...       WD           Normal     244000
# 4         5  527105010           60  ...       WD           Normal     189900
# ...     ...        ...          ...  ...       ...             ...        ...
# 2925   2926  923275080           80  ...       WD           Normal     142500
# 2926   2927  923276100           20  ...       WD           Normal     131000
# 2927   2928  923400125           85  ...       WD           Normal     132000
# 2928   2929  924100070           20  ...       WD           Normal     170000
# 2929   2930  924151050           60  ...       WD           Normal     188000
#
# [2930 rows x 81 columns]

# %% [markdown]
# In step 12, I have used isnull() function to find the sum of null values in each columns and we could see that Lot Frontage has maximum number of null values.

# %%
# Step 12: Finding the number of missing values in a dataset
ames2.isnull().sum()
# Out:
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 81, dtype: int64

# %% [markdown]
# Python provides users with various built-in functions to clean the data before doing any analysis on it. As seen in step 13, In this section instead of dropping null values I have replaced each null values with a valid values in a dataframe. We can replace NAN values in complete dataframe or a specific column. In this coursework, I have replaced each missing value and filled it with an average of its column and stored it in a ames3 dataframe. At the end I have verifed the same with .head function in step 14.

# %%
# Step 13: I have filled missing values with the mean
ames3=ames2.fillna(ames2.mean())

# %%
# Step 14: Get the first few rows after filling the columns with it's mean
ames3.head(20)
# Out:
#     Order        PID  MS SubClass  ... Sale Type  Sale Condition  SalePrice
# 0       1  526301100           20  ...       WD           Normal     215000
# 1       2  526350040           20  ...       WD           Normal     105000
# 2       3  526351010           20  ...       WD           Normal     172000
# 3       4  526353030           20  ...       WD           Normal     244000
# 4       5  527105010           60  ...       WD           Normal     189900
# 5       6  527105030           60  ...       WD           Normal     195500
# 6       7  527127150          120  ...       WD           Normal     213500
# 7       8  527145080          120  ...       WD           Normal     191500
# 8       9  527146030          120  ...       WD           Normal     236500
# 9      10  527162130           60  ...       WD           Normal     189000
# 10     11  527163010           60  ...       WD           Normal     175900
# ...

# %% [markdown]
# To cross verify the value, In step 15 I have used mean function to calculate the mean of Lot Frontage column and printed it in step 16. We could see mean of Lot Frontage column is 69.22459 and the mean value is inserted in row 11 for that column.

# %%
# Step 15: caluclate the mean of Lot Frontage column
df_mean = ames3[['Lot Frontage']].mean()

# %%
# Step 16: Printing the mean calculated in step 15
print(df_mean)
# Out:
# Lot Frontage    69.22459
# dtype: float64

# %% [markdown]
# Dataset used for analysis should not have any kind of duplicate values in it and if it has, we can use drop_duplicates() function to remove it. To check the duplicate rows I have used below function as seen in step 17, to find the number of duplicates but the result is false which means we have no duplicates.

# %%
# Step 17 : Find the duplicate values
ames3.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2925    False
# 2926    False
# 2927    False
# 2928    False
# 2929    False
# Length: 2930, dtype: bool

# %% [markdown]
# After performing all the above operations, we could say that data is clean to process ahead for further analysis

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# It is a intial process of exploring the data to find any kind of pattern or inconsistency with the graphical representation or summary statistics. Below mentioned are exploratory analysis techniques:
#
# Box-Plot: It is a way of presenting statistical data on a plot where rectangle is drawn to denote range and quartiles of data.
#
# Histogram: It is an exact portrayal of distributed numerical data.
#
# Trend analysis: It is a way of predicting furture values based on the previous data.
#
# Scatter Plots: It is a way of plotting points horizontally and vertically.

# %% [markdown]
# In the below step 17, I have used .corr function which can be used to find relationship among all columns within the dataframe. It can be used to find the significant information to do the further investigation.
# In the below analysis, we have found 10 most important factor which is directly related with the SalePrice.

# %%
# Step 17: Top 10 mathematical factors profoundly connected with SalePrice
corr_mat = ames3.corr().SalePrice.sort_values(ascending=False)
corr_mat.head(11)
# Out:
# SalePrice         1.000000
# Overall Qual      0.799262
# Gr Liv Area       0.706780
# Garage Cars       0.647861
# Garage Area       0.640385
# Total Bsmt SF     0.632105
# 1st Flr SF        0.621676
# Year Built        0.558426
# Full Bath         0.545604
# Year Remod/Add    0.532974
# Garage Yr Blt     0.510684
# Name: SalePrice, dtype: float64

# %% [markdown]
# From the below exploration using box plot in step 18, we could see that the quality is one of the major factor to decide the prices, at which the houses are sold. From this pattern, it is Obvious that greater quality makes the house more costly. In this section, I have used box-plot because it is easier to recognize the mean values.

# %%
# Step 18: Measuring the overall quality
plt.figure(figsize=(6, 4))
heading = plt.title('Cost of House based on Overall Quality')
# Using boxplot to set x and y axis and setting the palette color to brown and green
sns.boxplot(x='Overall Qual', y='SalePrice', data=ames3, palette='BrBG')

# %% [markdown]
# Strangely in the results of step 19, it could be seen that the houses with carport which can keep 4 vehicles are less expensive as compared to the houses with 3-vehicle carport which shows the inconsistency of data.

# %%
# Step 19: Measuring the cost based on Garage size
plt.figure(figsize=(6, 4))
heading = plt.title('Cost of house based on Garage Size')
# Using boxplot to set x and y axis and setting the palette color to brown and green
sns.boxplot(x='Garage Cars', y='SalePrice', data=ames3, palette='BrBG')

# %% [markdown]
# We should be aware of any outliers present within the dataset. For example properties with bigger living area is cheaper as compared to those of smaller living area. To determine connection between 2 numeric values and investigate any such outliers, I have used scatterplot in step 20.

# %%
# Step 20: Identifying outliers using scatterplot 
# figsize is used to set the size of figure used 
plt.figure(figsize=(6, 4))
# set_style to draw the background grid which is white
sns.set_style('whitegrid')
heading = plt.title('SalesPrice vs. LivingArea')
sns.scatterplot(x='Gr Liv Area', y='SalePrice', data=ames3)

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# Representing data and information graphically can be termed as data visualization. To do the data visualization we are using plots, statistical  graphics and various other tools to present the information effectively. In this coursework, I have mainly focused on matplot and seaborn visulaization.

# %% [markdown]
# ##**Numerical Data**

# %% [markdown]
# In step 21, I have used histogram for the visualization because it can present huge amount of data. We could see that the saleprice has skeqwed to the one side and maximum houses were sold within the price range between 100000-200000.

# %%
# Step 21: Calculating the total number of houses sold 
from matplotlib import cycler
# %matplotlib inline
plt.style.use('seaborn-white')
plt.xlabel('Sale price')
plt.ylabel('Total Number')
plt.title('Total Number of houses sold')
plt.hist(ames3.SalePrice)
colors = cycler('color',
                ['#EE6666', '#3388BB', '#9988DD',
                 '#EECC55', '#88BB44', '#FFBBBB'])
# I have used plt.rc function to alter some settings
plt.rc('axes', facecolor='#E6E6E6', edgecolor='none',
       axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)

# %% [markdown]
# I have used groupby to join month and year of the sale and plotted it using a bar graph to do the comparision between two segments. From step 22, it is clear that maximum number of houses were sold every year in the month of May, June and July and the least preferable month to buy a property is during the start and end of the year.

# %%
# Step 22: Plotting the monthly count of houses sold from the year 2006-2009
# Labelling the x-axis and y-axis
plt.ylabel('count')
plt.xlabel('Yr Sold, Mo Sold')
ames3.groupby(["Mo Sold", "Yr Sold"]).SalePrice.count().plot(kind="bar",figsize=(12,4))
# Set the heading
plt.title('When were houses sold?')
# Display all the figures
plt.show()

# %% [markdown]
# I have used scatter plot to identify the pattern in the below graph. In step 23, we could say that the age of the house is additionaly playing a significant role in determing the cost of the house. The houses which were built recently have higher average cost however there are a few houses worked before 1900 having an exorbitant cost.

# %%
# Step 23 : Using scatterplot to measure yearly salesprice of house
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Year Built', y='SalePrice', data=ames3)
# Set the title of image
heading = plt.title('Sales price of a house based on the year built')

# %% [markdown]
# As seen in step 25, it is seen StoneBr,Nridght,Noridge property sales prices are higher as compared to other neighbourhood in ames city.

# %%
#  Step 25: To determine in which neighbourhood, the sales price is higher I have used barplot
#  Setting the figure size
plt.figure(figsize=(20,5))
ax = sns.barplot(x=ames3["Neighborhood"], y=ames3["SalePrice"] )

# %% [markdown]
# In step 26, I have calculated the mean of sale price and printed the highest and lowest sales price of a house in step 27. From the observation we could see there were very few houses which were sold above 500000 and maximum were sold inbetween range of 100000-250000.

# %%
# Step 26: Calculating mean of SalesPrice
ames3["SalePrice"].mean()
# Out:
# 180796.0600682594

# %%
# Step 27: Printing the highest and lowest salesprice and calculating the mean and median
ames3.SalePrice.hist(bins=70, rwidth=.5, figsize=(10,4))
print('The normal deals cost is ${:,.0f}, while median is ${:,.0f}'.format(
    ames3.SalePrice.mean(), ames3.SalePrice.median()))
print('The least expensive house sold for ${:,.0f} and highest cost of house sold for ${:,.0f}'.format(
    ames3.SalePrice.min(), ames3.SalePrice.max()))
plt.title('How costly are houses?')
plt.show()
# Out:
# The normal deals cost is $180,796, while median is $160,000
# The least expensive house sold for $12,789 and highest cost of house sold for $755,000

# %% [markdown]
# ##**Categorical data**

# %% [markdown]
# From below graph in step 28, we could say that most preferred house styles to be built during the recent years were of 1 and 2 story styles however in the 90's, mostly houses of 2.5 Fin to 2.5 Unf were built.

# %%
# Step 28: Visualizing categorical data using boxplot
sns.boxplot(x=ames3["Year Built"], y=ames3["House Style"])

# %% [markdown]
# From the below analysis in step 29 and 30, we could see that there is a major disparity in the sales price among ames neighbourhood houses. StoneB,NridgHt and NoRidge are the 3 most costly area with median sales price of around $300,000 which is 3 times as high as the median of the 3 least expensive areas, which are MeadowV, DOTRR and BrDale.

# %%
# Step 29: Visualize categorical feature of property connected with saleprice
def visualizeCatFeature(feature):
    """
    Visualize categorical feature of property connected with saleprices 
    """
    # Arranging median saleprice in decending order 
    sale = ames3.groupby(
        [feature]).median().SalePrice.sort_values(ascending=False).index

    # Creating Box Plot
    sns.boxplot(x=feature,
                y='SalePrice',
                data=ames3,
                order=sale,
                palette='BrBG')

# %%
# Step 30: Visualizing SalesPrice based on Neighborhood using CatFeature
plt.figure(figsize=(10, 5))
visualizeCatFeature('Neighborhood')
heading = plt.title('Sales Price based on Neighborhood')
# Rotating the Text of Xticks Label 
kit = plt.xticks(rotation=45)

# %% [markdown]
# From the below analysis in step 31, we can see that most costly houses are made of Wood Shingles rooftop which costs between 300,000 to 450,000. However, there are many houses which are costly whose rooftop is made of composite Shingle.

# %%
# Step 31: Visualize Sales Price of a House based on Roof Material
# Set the figure size
plt.figure(figsize=(7, 5))
visualizeCatFeature('Roof Matl')
# Set the title of image
heading = plt.title('Sales Price of a House based on Roof Material')

# %% [markdown]
# As shown in step 32, we have visualized the correlation between multiple columns of ames dataset like YearBuilt and GarageYrBlt are correlated with each other which indicates that carports and houses were built together.
# Likewise we have also seen that correlation between KitchenQual and ExteriorQual which shows that the new houses built, most likely has a good kitchen and exterior.

# %%
# Step 32: Visualizing the correlation among columns 
# Computing the correlation matrix
corr = ames3[['SalePrice'] + numericalColumn].corr()
fig = plt.figure(figsize=(16,15))
ax = fig.add_subplot(111)
# To generate custom diverging color map
cmap = sns.diverging_palette(120, 10, as_cmap=True)
# Drawing the heatmap 
sns.heatmap(corr, 
                 yticklabels=corr.index.values,
                 xticklabels=corr.columns.values,
           cmap=cmap)
ax.xaxis.tick_top()
# Rotating the Text of Xticks Label 
plt.setp(ax.get_xticklabels(), rotation=90)
# Display all the figures
plt.show()

# %% [markdown]
# ##**Conclusion**

# %% [markdown]
# Ames dataset is a housing dataset which I have used to get various insights from.
# In this couserwork, I have cleaned the data and performed exploratory data analysis to know the data and analyze the important aspects of this dataset. After analyzing the dataset I have used matplotlib and seaborn to do the visualization. After performing the analysis, we could conclude that there are several factors which plays a significant role in determining the cost of the house and the most preferrable month to buy a house is May,June and July.

# %% [markdown]
# ##**References**
# https://datacarpentry.org/python-ecology-lesson/02-starting-with-data/
# https://realpython.com/pandas-python-explore-dataset/
# http://jse.amstat.org/v19n3/decock.pdf
#
# https://chriskhanhtran.github.io/minimal-portfolio/projects/ames-house-price.html
